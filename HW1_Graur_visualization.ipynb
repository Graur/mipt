# %% [markdown]
# <a href="https://colab.research.google.com/github/Graur/mipt/blob/master/HW1_Graur_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ДЗ № 1: Продвинутая визуализация данных (Граур Андрей)
#
# ### Задание 1. Знакомство с данными и EDA
# В этом домашнем задании мы будем работать с данными по рынку недвижимости в Нью-Йорке. Перед тем как проводить дата-анализ наших данных, необходимо провести разведочный анализ данных.

# %%
# Импортируем библиотеки и данные
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ny_housing = pd.read_csv("https://raw.githubusercontent.com/ElijahSum/mipt_visualization/master/week_01_visualization/data/NY-House-Dataset.csv")
ny_housing = ny_housing[ny_housing['PRICE'] <= 200000000]
ny_housing.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %% [markdown]
# ### Задание 1.1 Построить разные графики и сделать 6 выводов
# На этом этапе нам нужно выявить с помощью визуализаций разные паттерны и зависимости, распределение значений внутри переменных.
#
# Создайте 6 визуализаций разных видов. Можно использовать графики из галерей Matplotlib или Seaborn. Полученные графики отобразите и сохраните в отдельные переменные.
#
# Каждый график должен иметь все стандартные аттрибуты - подписи осей, название и другие необходимые детали.
#
# NB: Визуализация должна иметь смысл и нести новую информацию.

# %%
# Визуализация 1: Диаграмма рассеяния между ценой и площадью недвижимости
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PROPERTYSQFT', y='PRICE', data=ny_housing, color='orange')
plt.title('Зависимость цены от площади недвижимости')
plt.xlabel('Площадь недвижимости (кв. футы)')
plt.ylabel('Цена')
plt.grid(True)
plt.tight_layout()
plt.show()

# Вывод 1: Есть положительная зависимость между ценой и площадью недвижимости.

# %%
# Визуализация 2: Гистограмма цен на недвижимость
plt.figure(figsize=(10, 6))
sns.histplot(ny_housing['PRICE'], bins=60, kde=True, color='skyblue')
plt.title('Распределение цен на недвижимость в Нью-Йорке')
plt.xlabel('Цена')
plt.ylabel('Частота')
plt.grid(True)
plt.tight_layout()
plt.show()

# Вывод 2: Большинство цен на недвижимость расположены в нижней части диапазона.

# %%
# Визуализация 3: Столбчатая диаграмма количества недвижимости по типу
plt.figure(figsize=(10, 6))
sns.countplot(x='TYPE', data=ny_housing, palette='pastel')
plt.title('Количество недвижимости по типу')
plt.xlabel('Тип недвижимости')
plt.ylabel('Количество')
plt.xticks(rotation=45)
plt.show()

# Вывод 3: Больше всего в датасете квартир, затем домов и таунхаусов.
# Out:
# <ipython-input-12-baab1aa4676f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='TYPE', data=ny_housing, palette='pastel')

# %%
# Визуализация 4: Цены на недвижимость по типу
plt.figure(figsize=(10, 6))
sns.boxplot(x='TYPE', y='PRICE', data=ny_housing, palette='pastel')
plt.title('Цены на недвижимость по типу')
plt.xlabel('Тип недвижимости')
plt.ylabel('Цена')
plt.xticks(rotation=45)
plt.show()

# Вывод 4: Медианные цены на квартиры выше, чем на дома и таунхаусы.
# Out:
# <ipython-input-13-c90f6fecdfbd>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TYPE', y='PRICE', data=ny_housing, palette='pastel')

# %%
# Визуализация 5: Распределение числа спален
plt.figure(figsize=(10, 6))
sns.countplot(x='BEDS', data=ny_housing, palette='pastel')
plt.title('Распределение числа спален')
plt.xlabel('Число спален')
plt.ylabel('Частота')
plt.show()

# Вывод 5: Большинство недвижимости имеют 3 или 2 спальни.
# Out:
# <ipython-input-14-5fa230c65bea>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='BEDS', data=ny_housing, palette='pastel')

# %%
# Визуализация 6: Корреляционная матрица для числовых признаков
plt.figure(figsize=(10, 6))
sns.heatmap(ny_housing.corr(), annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица')
plt.show()

# Вывод 6: Есть высокая корреляция между ценой и площадью недвижимости.
# Out:
# <ipython-input-15-6c421b8fc1ff>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ny_housing.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# ### Задание 1.2 Сбор дашборда
# В рамках модуля мы научились использовать функцию plt.subplots для создания "полотна" с целью отображения нескольких графиков на одном поле. Создайте полотно размером 3x2 (три строки и два столбца). На этом полотне изобразите все графики, которые ранее были созданы в Задании 1.1.

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 15))

# Гистограмма цен на недвижимость
sns.histplot(ny_housing['PRICE'], bins=20, kde=True, color='skyblue', ax=axes[0, 0])
axes[0, 0].set_title('Распределение цен на недвижимость в Нью-Йорке')
axes[0, 0].set_xlabel('Цена')
axes[0, 0].set_ylabel('Частота')

# Диаграмма рассеяния между ценой и площадью недвижимости
sns.scatterplot(x='PROPERTYSQFT', y='PRICE', data=ny_housing, color='orange', ax=axes[0, 1])
axes[0, 1].set_title('Зависимость цены от площади недвижимости')
axes[0, 1].set_xlabel('Площадь недвижимости (кв. футы)')
axes[0, 1].set_ylabel('Цена')

# Столбчатая диаграмма количества недвижимости по типу
sns.countplot(x='TYPE', data=ny_housing, palette='pastel', ax=axes[1, 0])
axes[1, 0].set_title('Количество недвижимости по типу')
axes[1, 0].set_xlabel('Тип недвижимости')
axes[1, 0].set_ylabel('Количество')
axes[1, 0].tick_params(axis='x', rotation=45)

# Цены на недвижимость по типу
sns.boxplot(x='TYPE', y='PRICE', data=ny_housing, palette='pastel', ax=axes[1, 1])
axes[1, 1].set_title('Цены на недвижимость по типу')
axes[1, 1].set_xlabel('Тип недвижимости')
axes[1, 1].set_ylabel('Цена')
axes[1, 1].tick_params(axis='x', rotation=45)

# Корреляционная матрица для числовых признаков
sns.heatmap(ny_housing.corr(), annot=True, cmap='coolwarm', ax=axes[2, 0])
axes[2, 0].set_title('Корреляционная матрица')

# Распределение числа спален
sns.countplot(x='BEDS', data=ny_housing, palette='pastel', ax=axes[2, 1])
axes[2, 1].set_title('Распределение числа спален')
axes[2, 1].set_xlabel('Число спален')
axes[2, 1].set_ylabel('Частота')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-a06808936f13>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='TYPE', data=ny_housing, palette='pastel', ax=axes[1, 0])
# <ipython-input-17-a06808936f13>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TYPE', y='PRICE', data=ny_housing, palette='pastel', ax=axes[1, 1])
# <ipython-input-17-a06808936f13>:31: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ny_housing.corr(), annot=True, cmap='coolwarm', ax=axes[2, 0])
# <ipython-input-17-a06808936f13>:35: FutureWarning:
# ...

# %% [markdown]
# ### Задание 1.3
# Интерпретируйте полученные результаты. К каждому графику напишите описание - какую полезную информацию мы получили в результате использования этой визуализации. Постарайтесь сделать это максимально подробно и полно.

# %% [markdown]
# ### Выводы:
#
# 1) Гистограмма цен на недвижимость:
#         Этот график позволяет нам увидеть распределение цен на недвижимость в Нью-Йорке.
#         Мы видим, что большинство цен сконцентрированы в нижней части диапазона, что может свидетельствовать о том, что в основном представлены более доступные объекты недвижимости.
#
# 2) Диаграмма рассеяния между ценой и площадью недвижимости:
#         Эта визуализация позволяет нам оценить связь между ценой и площадью недвижимости.
#         Мы видим положительную зависимость между ценой и площадью недвижимости, что означает, что более просторные объекты недвижимости имеют более высокие цены.
#
# 3) Столбчатая диаграмма количества недвижимости по типу:
#         Этот график помогает нам понять распределение различных типов недвижимости в датасете.
#         Мы видим, что наиболее распространенными типами недвижимости являются квартиры, за которыми следуют дома и таунхаусы.
#
# 4) Boxplot для цен на недвижимость по типу:
#         Эта визуализация демонстрирует распределение цен на недвижимость в зависимости от ее типа.
#         Мы видим, что медианные цены на квартиры выше, чем на дома и таунхаусы, а также различия в разбросе цен между разными типами недвижимости.
#
# 5) Корреляционная матрица для числовых признаков:
#         Этот график позволяет нам оценить степень корреляции между различными числовыми признаками.
#         Мы видим, что существует высокая положительная корреляция между ценой и площадью недвижимости, что подтверждает вывод из второй визуализации.
#
# 6) Распределение числа спален:
#         Этот график позволяет нам увидеть распределение числа спален в объектах недвижимости.
#         Мы видим, что большинство объектов имеют 2 или 3 спальни, что может указывать на типичные параметры для большинства представленной недвижимости.
#
# Использование каждой из этих визуализаций позволяет нам лучше понять особенности и характеристики рынка недвижимости в Нью-Йорке, а также выявить важные закономерности и зависимости между различными переменными.

# %% [markdown]
# ### Задание 1.4 Как район влияет на стоимость жилья?
# В наших данных есть столбец TYPE, отвечающий за тип проданной недвижимости (квартира, дом, таунхаус и т.д.).
#
# Создайте barplot, на котором будет показана средняя стоимость недвижимости разных типов в New York County (столбец SUBLOCALITY).

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='TYPE', y='PRICE', data=ny_housing[ny_housing['SUBLOCALITY'] == 'New York County'], ci=None, palette='pastel')
plt.title('Средняя стоимость недвижимости разных типов в New York County')
plt.xlabel('Тип недвижимости')
plt.ylabel('Средняя цена')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-18-dbaf6402738e>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='TYPE', y='PRICE', data=ny_housing[ny_housing['SUBLOCALITY'] == 'New York County'], ci=None, palette='pastel')
# <ipython-input-18-dbaf6402738e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TYPE', y='PRICE', data=ny_housing[ny_housing['SUBLOCALITY'] == 'New York County'], ci=None, palette='pastel')

# %% [markdown]
# ### Задание 1.5 Какой тип квартир самый популярный в разных районах?
# В столбце SUBLOCALITY указан район расположения объектов недвижимости. Всего в этом столбце 21 разных районов. Однако некоторые из них содержат слишком маленькое количество наблюдений.
#
# Оставьте только те районы (столбец SUBLOCALITY), количество наблюдений в которых больше или равно 100.
# Для оставшихся районов сделайте barh plot, в котором для каждого района будет указана доля квартир разных видов (столбец TYPE).
# Полученные значения отсортируйте по убыванию по доле квартир (Condo for sale).
# Подсказка: аналогичный алгоритм мы рассматривали на лекции в ходе вычисления доли женщин, берущих кредит.
#
# Отлично! Теперь мы ориентируемся в данных, понимаем их структуру и особенности. Можно переходить к очистке от выбросов перед созданием модели.

# %%
count = ny_housing['SUBLOCALITY'].value_counts()
sl = count[count >= 100].index
data = ny_housing[ny_housing['SUBLOCALITY'].isin(sl)]
groupby = data.groupby(['SUBLOCALITY', 'TYPE']).size().unstack(fill_value=0)
pct = groupby.div(groupby.sum(axis=1), axis=0)
sorted= pct.sort_values(by='Condo for sale', ascending=False).plot(kind='barh', stacked=True, figsize=(15, 10))
plt.title('Доля квартир разных типов в разных районах')
plt.xlabel('Доля квартир')
plt.ylabel('Район')
plt.legend(title='Тип')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Задание 2. Работа с выбросами
# ### Задание 2.1 Поиск выбросов
# В нашем датасете есть два признака, в которых могут находиться выбросы — PRICE и PROPERTYSQFT
#
# Почему их не может быть в других числовых переменных?
# Используя boxplot идентифицируйте выбросы в обеих переменных в зависимости от типа недвижимости (TYPE).

# %% [markdown]
# Выбросы в данных могут возникать в разных переменных по разным причинам, но в основном это связано с неточностями в данных или ошибками в сборе информации. В случае с переменными PRICE и PROPERTYSQFT, возможны выбросы из-за различий в ценах на недвижимость и ее площади. Например, квартира с аномально высокой ценой или очень большой площадью может считаться выбросом. Однако в других числовых переменных, таких как количество спален (BEDS) или количество ванных комнат (BATH), выбросы могут быть менее вероятными, так как они, скорее всего, ограничены физическими параметрами (например, размером квартиры).
#
# Чтобы идентифицировать выбросы в переменных PRICE и PROPERTYSQFT в зависимости от типа недвижимости, мы можем использовать boxplot. Boxplot позволяет нам визуализировать распределение данных, выделяя выбросы в виде точек за пределами ящика.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='TYPE', y='PRICE', data=ny_housing, palette='pastel')
plt.title('Boxplot цен на недвижимость в зависимости от типа')
plt.xlabel('Тип недвижимости')
plt.ylabel('Цена')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(x='TYPE', y='PROPERTYSQFT', data=ny_housing, palette='pastel')
plt.title('Boxplot площади недвижимости в зависимости от типа')
plt.xlabel('Тип недвижимости')
plt.ylabel('Площадь недвижимости')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-32-efbe4fc1c1f6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TYPE', y='PRICE', data=ny_housing, palette='pastel')
# <ipython-input-32-efbe4fc1c1f6>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TYPE', y='PROPERTYSQFT', data=ny_housing, palette='pastel')

# %% [markdown]
# ### Задание 2.2 Удаление выбросов
# Удалите выбросы в датасете по переменной PRICE, которые были обнаружены в задании 2.1.
#
# После удаления выведите bar plot, который будет визуализировать среднюю стоимость недвижимости в зависимости от типа недвижимости.

# %%
q1 = ny_housing['PRICE'].quantile(0.25)
q3 = ny_housing['PRICE'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

ny_housing_no_outliers = ny_housing[(ny_housing['PRICE'] >= lower_bound) & (ny_housing['PRICE'] <= upper_bound)]

print("Размер датасета до удаления выбросов:", ny_housing.shape)
print("Размер датасета после удаления выбросов:", ny_housing_no_outliers.shape)
# Out:
# Размер датасета до удаления выбросов: (4800, 17)
# Размер датасета после удаления выбросов: (4242, 17)

# %%
# Создание bar plot для средней стоимости недвижимости по типу
plt.figure(figsize=(10, 6))
sns.barplot(x='TYPE', y='PRICE', data=ny_housing_no_outliers, estimator=np.mean, palette='pastel')
plt.title('Средняя стоимость недвижимости по типу')
plt.xlabel('Тип недвижимости')
plt.ylabel('Средняя цена')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-35-dc839c8b668c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TYPE', y='PRICE', data=ny_housing_no_outliers, estimator=np.mean, palette='pastel')

# %% [markdown]
# ### Задание 2.3 Поиск выбросов с помощью правила трёх сигм
# С помощью правила трех сигм найдите, какие значения являются экстремальными (выбросами) в столбце PROPERTYSQFT. Результат выведите в текстовом виде и сравните с результатом, полученным с помощью box plot в задании 2.1.

# %%
mean_propertysqft = ny_housing['PROPERTYSQFT'].mean()
std_propertysqft = ny_housing['PROPERTYSQFT'].std()
lower_bound = mean_propertysqft - 3 * std_propertysqft
upper_bound = mean_propertysqft + 3 * std_propertysqft
outliers_propertysqft = ny_housing[(ny_housing['PROPERTYSQFT'] < lower_bound) | (ny_housing['PROPERTYSQFT'] > upper_bound)]
print("Экстремальные значения (выбросы) в столбце PROPERTYSQFT:")
print(outliers_propertysqft)
# Out:
# Экстремальные значения (выбросы) в столбце PROPERTYSQFT:
#                                             BROKERTITLE  \
# 1                                   Brokered by Serhant
# 4     Brokered by Sotheby's International Realty - E...
# 7                     Brokered by Connie Profaci Realty
# 69    Brokered by Sotheby's International Realty - E...
# 99        Brokered by Douglas Elliman - 575 Madison Ave
# 141       Brokered by Douglas Elliman - 575 Madison Ave
# 181                                 Brokered by COMPASS
# 222        Brokered by CHRISTIE'S INT.REAL ESTATE GROUP
# 601   Brokered by Peter Ashe Real Estate- Peter Ashe...
# 622                Brokered by Momentum Real Estate Llc
# 765                             Brokered by RE MAX Edge
# 823                 Brokered by Andrew Lichtenstein Inc
# 917                                 Brokered by COMPASS
# 936              Brokered by EXIT REALTY TOP PROPERTIES
# 969             Brokered by Robert Defalco Realty, Inc.
# ...

# %% [markdown]
# ### Задание 2.4 Выделение выбросов
# Мы нашли значение, после которого все наши наблюдения можно назвать выбросами.
#
# Подсветите их. Для этого создайте scatter plot (столбцы PROPERTYSQFT и PRICE) в котором все точки выше этого значения PROPERTYSQFT будут помечены красным цветом.
#
# После этого удалите эти значения из датасета (сортировка по переменной PROPERTYSQFT).
#
# Отлично, теперь можем перейти к построению простой модели.

# %%
outlier_threshold = ny_housing['PROPERTYSQFT'].max()
plt.figure(figsize=(10, 6))
plt.scatter(ny_housing['PROPERTYSQFT'], ny_housing['PRICE'], c='blue', alpha=0.5, label='Обычные наблюдения')
plt.scatter(ny_housing[ny_housing['PROPERTYSQFT'] > outlier_threshold]['PROPERTYSQFT'], ny_housing[ny_housing['PROPERTYSQFT'] > outlier_threshold]['PRICE'], c='red', alpha=0.5, label='Выбросы')
plt.title('Scatter Plot для переменных PROPERTYSQFT и PRICE')
plt.xlabel('PROPERTYSQFT')
plt.ylabel('PRICE')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
ny_housing_no_outliers = ny_housing[ny_housing['PROPERTYSQFT'] <= outlier_threshold]

# %% [markdown]
# ## Задание 3. Создание простой модели, визуализация результатов работы алгоритма
# ### Задание 3.1 Создание модели парной регрессии
# В рамках других курсах вы проходили довольно много различных моделей и хорошо в них ориентируйтесь. Давайте сейчас попробуем посмотреть, в чем нам может помочь визуализация при интерпретации моделей.
#
# Используя любую удобную для вас библиотеку, создайте модель простейшей парной регрессии. В качестве зависимой переменной используйте PRICE, в качестве независимой - PROPERTYSQFT. Полученные коэффициенты выведите и кратко опишите (логичным ли получился результат?)

# %%
from sklearn.linear_model import LinearRegression
X = ny_housing_no_outliers[['PROPERTYSQFT']]
y = ny_housing_no_outliers['PRICE']
model = LinearRegression()
model.fit(X, y)
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Коэффициент наклона (slope): 846.3128969645334
# Свободный член (intercept): 62893.53354392573

# %% [markdown]
# Выводы:
#
#   - Коэффициент наклона (slope): показывает, на сколько увеличивается цена недвижимости (PRICE) при увеличении площади недвижимости (PROPERTYSQFT) на одну единицу. Чем больше этот коэффициент, тем сильнее влияние площади на цену.
#   - Свободный член (intercept): это значение цены, когда площадь недвижимости равна нулю. В данном контексте оно малоинтерпретируемо, так как нулевая площадь недвижимости не имеет смысла.

# %% [markdown]
# ### Задание 3.2 Визуализация результата
# Когда мы работаем с парной регрессией, нам интересно отобразить полученные результаты на графике и визуально оценить их.
#
# Создайте scatter plot, где по оси x будет находится PROPERTYSQFT, а по оси y - PRICE. Добавьте на этот график прямую регрессионного уравнения, которая у нас получилась.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(ny_housing_no_outliers['PROPERTYSQFT'], ny_housing_no_outliers['PRICE'], c='blue', alpha=0.5, label='Наблюдения')
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Линейная регрессия')
plt.title('Scatter Plot и линейная регрессия для PRICE и PROPERTYSQFT')
plt.xlabel('PROPERTYSQFT')
plt.ylabel('PRICE')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bonus. Визуализация геоданных
# Некоторые типы визуализаций работают с конкретными типами данных. Вы могли заметить, что в нашем датасете есть столбцы LATITUDE и LONGITUDE - широта и долгота соответственно. Благодаря этим столбцам мы можем пространственно локализовать наши данные, а значит, создать карту.
#
# К сожалению в библиотеках matplotlib и seaborn отсутствует функционал создания карт. Однако создавать карты можно с помощью других библиотек. Одна из наиболее популярных - библиотека folium. Именно ей мы и воспользуемся.
#
# Давайте для начала скачаем folium.

# %%
# !pip install folium

# %% [markdown]
# Теперь мы можем начинать. В библиотеке folium есть отдельный тип данных folium.map, который позволяет создавать карту. В ходе создания нужно задать два параметра: location - ширина и долгота стартового расположения карты, а также zoom_start - стартовое приближение.

# %%
import folium

map = folium.Map(location=[40.7, -73.9], zoom_start=10)

# %% [markdown]
# Чтобы добавить точки на карту, необходимо воспользоваться следующими функциями:
#
# folium.Marker для создания объекта точки на карте.
# folium.add_to для добавления объекта на карту.
# Давайте создадим список парных списков, в каждом из которых будет хранится ширина и долгота объекта. Выберем только 500 первых наблюдений в датасете, чтобы не перегружать систему. В качестве описания наших точек (параметр popup) будем использовать цену. А направляя курсор на точку будем отобращать адрес (параметр tooltip).
#
# Давайте создадим эту карту:

# %%
points = ny_housing[['LATITUDE', 'LONGITUDE']].values.tolist()[:500]

for i, point in enumerate(points):
    folium.Marker(
        point,
        popup=str(ny_housing['PRICE'].iloc[i]),
        tooltip=ny_housing['MAIN_ADDRESS'].iloc[i]
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
